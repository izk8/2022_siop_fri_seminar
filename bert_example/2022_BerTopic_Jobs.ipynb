# %%
# %%capture
# !pip install bertopic

# %%
import pandas as pd
from bertopic import BERTopic

# %%
#df = pd.read_csv("https://raw.githubusercontent.com/izk8/2019_SIOP_Machine_Learning_Winners/master/full_data/2019_siop_ml_comp_data.csv")
#df = pd.read_json("/content/indeed_com-indeed_com_usa_jobs__20200101_20200331_deduped_n_merged_20201027_043720103677161.ldjson", lines=True)
df = pd.read_json("/content/drive/MyDrive/indeed_com-indeed_com_usa_jobs__20200101_20200331_deduped_n_merged_20201027_043720103677161.ldjson", lines=True)

# %%
df.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'url', 'job_title', 'category',
#        'company_name', 'city', 'state', 'country', 'post_date',
#        'job_description', 'inferred_salary_currency', 'job_board', 'geo',
#        'job_post_lang', 'inferred_iso2_lang_code', 'inferred_iso3_lang_code',
#        'site_name', 'html_job_description', 'domain', 'postdate_yyyymmdd',
#        'has_expired', 'last_expiry_check_date', 'latest_expiry_check_date',
#        'duplicate_status', 'postdate_in_indexname_format', 'inferred_city',
#        'inferred_state', 'inferred_country', 'fitness_score',
#        'company_description', 'salary_offered', 'contact_email',
#        'inferred_salary_from', 'inferred_salary_to',
#        'inferred_salary_time_unit'],
#       dtype='object')

# %%
df = df[:10000] # shorten it for demo purposes

# %%
df = df[['job_title','category','job_description']]

# %%
job_des = df["job_description"].to_list()

# %%
topic_model = BERTopic(language="english", calculate_probabilities=True, verbose=True, embedding_model="all-MiniLM-L6-v2")

# %%
topics, probs = topic_model.fit_transform(job_des)
# Out:
# Batches:   0%|          | 0/313 [00:00<?, ?it/s]
# 2022-04-12 16:59:17,006 - BERTopic - Transformed documents to Embeddings
# 2022-04-12 16:59:35,057 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-12 16:59:41,009 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
freq = topic_model.get_topic_info(); freq.head(1000)
# Out:
#      Topic  Count                                          Name
# 0       -1   3824                              -1_and_the_to_of
# 1        0    384              0_food_restaurant_kitchen_guests
# 2        1    300         1_students_teacher_classroom_children
# 3        2    277            2_accounting_financial_tax_finance
# 4        3    196            3_mental_services_social_treatment
# ..     ...    ...                                           ...
# 129    128     11      128_cleaning_residents_clean_housekeeper
# 130    129     11            129_network_systems_system_windows
# 131    130     10  130_manufacturing_engineering_process_launch
# 132    131     10                    131_coca_cola_sales_abarta
# 133    132     10          132_volunteer_outreach_grant_program
#
# [134 rows x 3 columns]

# %%
representative_docs = topic_model.get_representative_docs(0)
representative_docs
# Out:
# ['Our Tombstone and Bisbee wine tasting room is looking for a part time Tasting Room Sales Associate to add to our team. Candidates must be dependable, reliable, charismatic, courteous & pleasant, energetic, self-motivated, and professional. The position involves serving and selling wine, educating guests about wine, winemaking, and the local wine industry. All candidates must be computer and phone literate and have the ability to perform physical duties (tidying up the tasting room, lifting cases of wine, standing long periods). Will be asked to work alone and in a team environment, must be able to work with varying personalities. All candidates must be able to work weekends and Holidays. To apply: Please email a current resume with references and their contact information. Also include your earliest available start date. Requirements: Excellent customer service skills Excellent communication skills Must be 21 Must be able to lift 50 pounds repeatedly Ability to sell wine and wine c
# ...

# %%
representative_docs = topic_model.get_representative_docs(1)
representative_docs
# Out:
# ['The Eastern Hills Educational Building, an Ohio Department of Education Chartered School located in the Anderson-Withamsville area, is looking to hire both part-time and full-time morning, and afternoon, lead teachers and teaching aides for infant, toddler, and preschool ages. Employee children 18 months or older attend free. Hours: Approximately 7:00 am to 1:00 pm, and 1:00 pm to 6:45 pm. Call 513-528-4183.\n\nVisit us at EasternHillsChildCare.com\n\nJob Types: Full-time, Part-time\n\nSalary: $10.50 to $12.00 /hour\n\nEducation:\n\nHigh school or equivalent (Required)\n\nLanguage:\n\nEnglish (Required)\n\nWork authorization:\n\nUnited States (Required)\n\nWork Location:\n\nOne location\n\nThis Job Is:\n\nA good fit for applicants with gaps in their resume, or who have been out of the workforce for the past 6 months or more\n\nA good job for someone just entering the workforce or returning to the workforce with limited experience and education\n\nOpen to applicants who do not have 
# ...

# %%
representative_docs = topic_model.get_representative_docs(2)
representative_docs
# Out:
# ['Reports To: Shareholders and Managers Job Summary: We are looking for a professional to join our accounting services team. As a part of our team you will provide accounting services, including bookkeeping and payroll services, to a variety of clients. We are a full-service CPA firm and provide full scope accounting and bookkeeping. Salary and Benefits: Commensurate with experience, standard firm benefits (see below) Major Responsibilities: Develop and maintain relationships with clients and team members Bookkeeping services which include processing, analyzing and tracking disbursements, expenses, cash receipts or revenue transactions and other general ledger transactions Accounting services which include reconciliations of general ledger accounts and period end financial reports Process payroll and prepare payroll quarterly and year-end reports Research and analyze accounting, bookkeeping and QuickBooks issues Accounting projects and client assistance with accounting matters Proact
# ...

# %%
topic_model.get_topic(0)  # Select the most frequent topic
# Out:
# [('food', 0.02405504314620509),
#  ('restaurant', 0.017052000548292565),
#  ('kitchen', 0.011196064484578092),
#  ('guests', 0.008375185625578761),
#  ('service', 0.007856503065261842),
#  ('all', 0.007430358085103184),
#  ('and', 0.0073110276505038265),
#  ('guest', 0.007286842920003284),
#  ('cook', 0.0072630730613032785),
#  ('to', 0.007096985582763487)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
topic_model.visualize_distribution(probs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-192-6da7be5004c0> in <module>()
# ----> 1 topic_model.visualize_distribution(probs)
#
# /usr/local/lib/python3.7/dist-packages/bertopic/_bertopic.py in visualize_distribution(self, probabilities, min_probability, width, height)
#    1097                                                min_probability=min_probability,
#    1098                                                width=width,
# -> 1099                                                height=height)
#    1100
#    1101     def visualize_hierarchy(self,
#
# /usr/local/lib/python3.7/dist-packages/bertopic/plotting/_distribution.py in visualize_distribution(topic_model, probabilities, min_probability, width, height)
#      37     """
#      38     if len(probabilities.shape) != 1:
# ...

# %%
probs
# Out:
# array([[2.66552843e-003, 3.25290872e-003, 1.01929986e-002, ...,
#         3.61838563e-003, 4.71631540e-003, 2.92205621e-003],
#        [2.28557987e-003, 2.62619504e-003, 8.32952263e-003, ...,
#         3.04011202e-003, 3.96899144e-003, 2.36666705e-003],
#        [5.75042439e-003, 2.57699747e-003, 3.84260176e-003, ...,
#         7.21564158e-003, 1.41791244e-002, 2.40703552e-003],
#        ...,
#        [1.20084997e-003, 1.68025398e-003, 3.25371484e-003, ...,
#         3.66214323e-003, 2.50392141e-003, 1.53616464e-003],
#        [1.85709664e-003, 3.90982665e-003, 2.54713756e-003, ...,
#         2.61475294e-003, 2.17650915e-003, 6.13965285e-003],
#        [7.56819725e-308, 2.69401572e-307, 1.07395398e-307, ...,
#         1.02521255e-307, 8.66760446e-308, 5.87901173e-307]])

# %%
probs

# %%
topic_model.visualize_hierarchy(top_n_topics=1000)

# %%
topic_model.visualize_barchart(top_n_topics=20, n_words = 15)

# %%
topic_model.visualize_heatmap( width=1000, height=1000)

# %%
df['category'].unique()

# %%
len(df['category'].unique())

# %%
new_topics, new_probs = topic_model.reduce_topics(job_des, topics, probs, nr_topics=27)

# %%
freq = topic_model.get_topic_info(); freq.head(1000)

# %%
topic_model.get_topic(0)

# %%
topic_model.visualize_topics()

# %%
topic_model.visualize_heatmap( width=1000, height=1000)

# %%
topic_model.visualize_barchart(top_n_topics=20, n_words = 15)

# %%
topic_model.visualize_hierarchy(top_n_topics=1000)

# %%
similar_topics, similarity = topic_model.find_topics("Data", top_n=5); similar_topics

# %%
representative_docs = topic_model.get_representative_docs(4)
representative_docs

# %%
labels = df["category"]

# %% [markdown]
#  namely (semi)-supervised topic modeling! This allows us to steer the dimensionality reduction of the embeddings into a space that closely follows any labels you might already have. In other words, we use a semi-supervised UMAP instance to reduce the dimensionality of embeddings before clustering the documents with HDBSCAN.

# %%
labels

# %%
import random
random_labels= labels.sample(int( len(df)*.05)) 
random_labels

# %%
df = df.merge(random_labels, how = "left", left_index = True, right_index=True)  
df

# %%
# fill NaN with -1 
df = df.fillna(-1)
df

# %%
y = df["category_y"]

# %%
y

# %%
y = [label if label in indices else -1 for label in categories]

# %%
indices = [category_names.index(label) for label in labels_to_add]

# %%
random_labels.unique()

# %%
topic_model = BERTopic(verbose=True).fit(job_des, y=y)

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

data = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))
docs = data["data"]
categories = data["target"] # actual labels, turned into a number
category_names = data["target_names"] # actual names of those numbers...

# %%
labels_to_add = ['comp.graphics', 'comp.os.ms-windows.misc',
              'comp.sys.ibm.pc.hardware', 'comp.sys.mac.hardware',
              'comp.windows.x',]
indices = [category_names.index(label) for label in labels_to_add]
y = [label if label in indices else -1 for label in categories]

# %%
len(category_names)

# %%
category_names = df["category_x"].unique().tolist()

# %%
category_names

# %%
all_cat_indicies = [category_names.index(label) for label in category_names]

# %%
df["cat_indicies"] = [category_names.index(label) for label in df["category_x"]]
# list comprehension for this 
#for label in df["category_x"]:
#  category_names.index(label)

# %%
labels_to_add = ['Sales','Restaurant-or-food-Service','Computer-or-internet', 'Upper-Management-or-consulting']

# %%
indices_to_add = [category_names.index(label) for label in labels_to_add]
indices_to_add

# %%
y = [label if label in indices_to_add else -1 for label in df["cat_indicies"]]

# %%
set(y)

# %%
topic_model = BERTopic(verbose=True).fit(job_des, y=y)

# %%
freq = topic_model.get_topic_info(); freq.head(1000)

# %%
topic_model.visualize_barchart(top_n_topics=20, n_words = 15)

# %% [markdown]
# The topic model will be much more attuned to the categories that were defined previously. However, this does not mean that only topics for these categories will be found. BERTopic is likely to find more specific topics in those you have already defined. This allows you to discover previously unknown topics!

# %%
topic_model = BERTopic(verbose=True).fit(job_des, y=df['cat_indicies'])

# %%
topic_model.visualize_barchart(top_n_topics=20, n_words = 15)

# %%
freq = topic_model.get_topic_info(); freq.head(1000)

# %%
topic_model.visualize_hierarchy(top_n_topics=1000)
